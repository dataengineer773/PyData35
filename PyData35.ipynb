# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_json("example.json")
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
import sys
data.to_json(sys.stdout)
data.to_json(sys.stdout, orient="records")
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}[{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\dell\miniconda3\lib\site-packages (5.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\dell\miniconda3\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\dell\miniconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\dell\miniconda3\lib\site-packages (from html5lib) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
tables = pd.read_html("fdic_failed_bank_list.html")
len(tables)
failures = tables[0]
failures.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
close_timestamps = pd.to_datetime(failures["Closing Date"])
close_timestamps.dt.year.value_counts()
# Out:
# Closing Date
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: count, dtype: int64

# %%
from lxml import objectify

path = "Performance_MNR.xml"
with open(path) as f:
    parsed = objectify.parse(f)
root = parsed.getroot()

# %%
data = []

skip_fields = ["PARENT_SEQ", "INDICATOR_SEQ",
               "DESIRED_CHANGE", "DECIMAL_PLACES"]

for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)

# %%
perf = pd.DataFrame(data)
perf.head()
# Out:
#             AGENCY_NAME                        INDICATOR_NAME  \
# 0  Metro-North Railroad  On-Time Performance (West of Hudson)
# 1  Metro-North Railroad  On-Time Performance (West of Hudson)
# 2  Metro-North Railroad  On-Time Performance (West of Hudson)
# 3  Metro-North Railroad  On-Time Performance (West of Hudson)
# 4  Metro-North Railroad  On-Time Performance (West of Hudson)
#
#                                          DESCRIPTION  PERIOD_YEAR  \
# 0  Percent of commuter trains that arrive at thei...         2008
# 1  Percent of commuter trains that arrive at thei...         2008
# 2  Percent of commuter trains that arrive at thei...         2008
# 3  Percent of commuter trains that arrive at thei...         2008
# 4  Percent of commuter trains that arrive at thei...         2008
#
#    PERIOD_MONTH            CATEGORY FREQUENCY INDICATOR_UNIT YTD_TARGET  \
# 0             1  Service Indicators         M              %       95.0
# 1             2  Service Indicators         M              %       95.0
# 2             3  Service Indicators         M              %       95.0
# 3             4  Service Indicators         M              %       95.0
# 4             5  Service Indicators         M              %       95.0
#
#   YTD_ACTUAL MONTHLY_TARGET MONTHLY_ACTUAL
# 0       96.9           95.0           96.9
# 1       96.0           95.0           95.0
# 2       96.3           95.0           96.9
# 3       96.8           95.0           98.3
# 4       96.6           95.0           95.8

# %%
perf2 = pd.read_xml(path)
perf2.head()
# Out:
#    INDICATOR_SEQ  PARENT_SEQ           AGENCY_NAME  \
# 0          28445         NaN  Metro-North Railroad
# 1          28445         NaN  Metro-North Railroad
# 2          28445         NaN  Metro-North Railroad
# 3          28445         NaN  Metro-North Railroad
# 4          28445         NaN  Metro-North Railroad
#
#                          INDICATOR_NAME  \
# 0  On-Time Performance (West of Hudson)
# 1  On-Time Performance (West of Hudson)
# 2  On-Time Performance (West of Hudson)
# 3  On-Time Performance (West of Hudson)
# 4  On-Time Performance (West of Hudson)
#
#                                          DESCRIPTION  PERIOD_YEAR  \
# 0  Percent of commuter trains that arrive at thei...         2008
# 1  Percent of commuter trains that arrive at thei...         2008
# 2  Percent of commuter trains that arrive at thei...         2008
# 3  Percent of commuter trains that arrive at thei...         2008
# 4  Percent of commuter trains that arrive at thei...         2008
#
#    PERIOD_MONTH            CATEGORY FREQUENCY DESIRED_CHANGE INDICATOR_UNIT  \
# 0             1  Service Indicators         M              U              %
# 1             2  Service Indicators         M              U              %
# 2             3  Service Indicators         M              U              %
# 3             4  Service Indicators         M              U              %
# 4             5  Service Indicators         M              U              %
#
#    DECIMAL_PLACES YTD_TARGET YTD_ACTUAL MONTHLY_TARGET MONTHLY_ACTUAL
# 0               1      95.00      96.90          95.00          96.90
# 1               1      95.00      96.00          95.00          95.00
# 2               1      95.00      96.30          95.00          96.90
# 3               1      95.00      96.80          95.00          98.30
# 4               1      95.00      96.60          95.00          95.80

# %%
frame = pd.read_csv("ex1.csv")
frame
frame.to_pickle("frame_pickle")

# %%
pd.read_pickle("frame_pickle")
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\dell\miniconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\dell\miniconda3\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
fec = pd.read_excel('HR_Employee_Data.xlsx')
fec
# Out:
#          Emp_Id  satisfaction_level  last_evaluation  number_project  \
# 0      IND02438                0.38             0.53               2
# 1      IND28133                0.80             0.86               5
# 2      IND07164                0.11             0.88               7
# 3      IND30478                0.72             0.87               5
# 4      IND24003                0.37             0.52               2
# ...         ...                 ...              ...             ...
# 14994  IND40221                0.40             0.57               2
# 14995  IND24196                0.37             0.48               2
# 14996  IND33544                0.37             0.53               2
# 14997  IND40533                0.11             0.96               6
# 14998  IND11649                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department  salary
# 0                          0      sales     low
# 1                          0      sales  medium
# 2                          0      sales  medium
# 3                          0      sales     low
# 4                          0      sales     low
# ...                      ...        ...     ...
# 14994                      0    support     low
# 14995                      0    support     low
# 14996                      0    support     low
# 14997                      0    support     low
# 14998                      0    support     low
#
# [14999 rows x 11 columns]

# %%
xlsx = pd.ExcelFile("ex1.xlsx")

# %%
xlsx.sheet_names
# Out:
# ['Sheet1']

# %%
xlsx.parse(sheet_name="Sheet1")
# Out:
#    Unnamed: 0.1  Unnamed: 0  a   b   c   d message
# 0             0           0  1   2   3   4   hello
# 1             1           1  5   6   7   8   world
# 2             2           2  9  10  11  12     foo

# %%
xlsx.parse(sheet_name="Sheet1", index_col=0)
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
frame = pd.read_excel("ex1.xlsx", sheet_name="Sheet1")
frame
# Out:
#    Unnamed: 0.1  Unnamed: 0  a   b   c   d message
# 0             0           0  1   2   3   4   hello
# 1             1           1  5   6   7   8   world
# 2             2           2  9  10  11  12     foo

# %%
pip install tables
# Out:
# Requirement already satisfied: tables in c:\users\dell\miniconda3\lib\site-packages (3.10.2)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\dell\miniconda3\lib\site-packages (from tables) (2.2.2)
# Requirement already satisfied: numexpr>=2.6.2 in c:\users\dell\miniconda3\lib\site-packages (from tables) (2.10.2)
# Requirement already satisfied: packaging in c:\users\dell\miniconda3\lib\site-packages (from tables) (23.2)
# Requirement already satisfied: py-cpuinfo in c:\users\dell\miniconda3\lib\site-packages (from tables) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in c:\users\dell\miniconda3\lib\site-packages (from tables) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\dell\miniconda3\lib\site-packages (from tables) (4.12.2)
# Requirement already satisfied: ndindex in c:\users\dell\miniconda3\lib\site-packages (from blosc2>=2.3.0->tables) (1.9.2)
# Requirement already satisfied: msgpack in c:\users\dell\miniconda3\lib\site-packages (from blosc2>=2.3.0->tables) (1.1.0)
# Requirement already satisfied: httpx in c:\users\dell\miniconda3\lib\site-packages (from blosc2>=2.3.0->tables) (0.27.0)
# Requirement already satisfied: anyio in c:\users\dell\miniconda3\lib\site-packages (from httpx->blosc2>=2.3.0->tables) (4.4.0)
# Requirement already satisfied: certifi in c:\users\dell\miniconda3\lib\site-packages (from httpx->blosc2>=2.3.0->tables) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\miniconda3\lib\site-packages (from httpx->blosc2>=2.3.0->tables) (1.0.5)
# Requirement already satisfied: idna in c:\users\dell\miniconda3\lib\site-packages (from httpx->blosc2>=2.3.0->tables) (3.7)
# Requirement already satisfied: sniffio in c:\users\dell\miniconda3\lib\site-packages (from httpx->blosc2>=2.3.0->tables) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dell\miniconda3\lib\site-packages (from httpcore==1.*->httpx->blosc2>=2.3.0->tables) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
frame = pd.DataFrame({"a": np.random.standard_normal(100)})
store = pd.HDFStore("mydata.h5")
store["obj1"] = frame
store["obj1_col"] = frame["a"]
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store["obj1"]
# Out:
#            a
# 0   0.411439
# 1  -0.182857
# 2   1.465928
# 3   0.852623
# 4   0.509041
# ..       ...
# 95  0.245117
# 96 -0.501759
# 97 -1.162344
# 98  0.654301
# 99 -0.203782
#
# [100 rows x 1 columns]

# %%
store.put("obj2", frame, format="table")
store.select("obj2", where=["index >= 10 and index <= 15"])
store.close()
